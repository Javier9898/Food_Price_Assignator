# %%
from tensorflow import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

# %%
model = tf.keras.models.load_model('fruits_new_model.h5')

# %%
banana= "[[1. 0. 0.]]"
manzana= "[[0. 1. 0.]]"
uva= "[[0. 0. 1.]]"

# %%
def prepare(filepath):
    training_date = []
    
    img_array = cv2.imread(filepath,cv2.COLOR_BGR2RGB)
    new_array = cv2.resize(img_array,(224,224))
    new_image =  new_array.reshape(-1,224,224,3)
    return new_image

# %%
filepath = 'uv.jpg'
img_array = cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)

plt.imshow(img_array)

# %%
test = model.predict([prepare(filepath='uv.jpg')], verbose=1)
if banana == str(test):
    print("Banana")
    categoria = "Banana"
elif manzana == str(test):
    print("Manzana")
    categoria = "Manzana"
elif uva == str(test):
    print("Uva")
    categoria = "Uva"
else:
    print("Reposicione el alimento en la balanza")
    catergoria = ""
# Out:
# 1/1 [==============================] - 0s 2ms/step
# Uva

# %%
print(test)
# Out:
# [[0. 0. 1.]]
